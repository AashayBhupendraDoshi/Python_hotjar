# %%
import matplotlib.pyplot as plt
from template_data import sparce_template, dense_template

# %%
x, y, x2, y2, x3, y3, x4, y4 = sparce_template()

# %%
x.shape
# Out:
# (2, 210)

# %%
y.shape
# Out:
# (210,)

# %%
# # plot the data
# fig = plt.figure()
# ax = fig.add_subplot(221)
# # plot x,y data with c as the color vector, set the line width of the markers to 0
# ax.scatter(x[0], x[1], c=y, lw=0)

# ax = fig.add_subplot(222)
# # plot x,y data with c as the color vector, set the line width of the markers to 0
# ax.scatter(x2[0], x2[1], c=y2, lw=0)

plt.subplot(2,2,1)
plt.scatter(x[0], x[1], c=y, marker='.')
plt.subplot(2,2,2)
plt.scatter(x2[0], x2[1], c=y2, marker='.')
plt.subplot(2,2,3)
plt.scatter(x3[0], x3[1], c=y3, marker='.')
plt.subplot(2,2,4)
plt.scatter(x4[0], x4[1], c=y4, marker='.')

# %%
x, y = dense_template()
plt.scatter(x[0], x[1], c=y, marker='.')
plt.show()
print(x.shape, y.shape)
# Out:
# (2, 14600) (14600,)
