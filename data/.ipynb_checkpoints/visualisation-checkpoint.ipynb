# %%
import matplotlib.pyplot as plt
from template_data import sparce_template

# %%
x,y, x2, y2, x3, y3, x4, y4 = sparce_template()

# %%
x.shape
# Out:
# (2, 210)

# %%
y.shape
# Out:
# (210,)

# %%
# plot the data
fig = plt.figure()
ax = fig.add_subplot(221)
# plot x,y data with c as the color vector, set the line width of the markers to 0
ax.scatter(x[0], x[1], c=y, lw=0)

ax = fig.add_subplot(222)
# plot x,y data with c as the color vector, set the line width of the markers to 0
ax.scatter(x2[0], x2[1], c=y2, lw=0)

# %%
# plot the data
fig = plt.figure()
ax = fig.add_subplot(221)
# plot x,y data with c as the color vector, set the line width of the markers to 0
ax.scatter(x3[0], x3[1], c=y3, lw=0)

ax = fig.add_subplot(222)
# plot x,y data with c as the color vector, set the line width of the markers to 0
ax.scatter(x4[0], x4[1], c=y4, lw=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 # plot the data
#       2 fig = plt.figure()
# ----> 3 ax = fig.add_subplot(112)
#       4 # plot x,y data with c as the color vector, set the line width of the markers to 0
#       5 ax.scatter(x2[0], x2[1], c=y2, lw=0)
#
# File c:\users\aashay doshi\desktop\projects\raft\venv\lib\site-packages\matplotlib\figure.py:746, in FigureBase.add_subplot(self, *args, **kwargs)
#     743         args = tuple(map(int, str(args[0])))
#     744     projection_class, pkw = self._process_projection_requirements(
#     745         *args, **kwargs)
# --> 746     ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     747     key = (projection_class, pkw)
#     748 return self._add_axes_internal(ax, key)
#
# File c:\users\aashay doshi\desktop\projects\raft\venv\lib\site-packages\matplotlib\axes\_subplots.py:36, in SubplotBase.__init__(self, fig, *args, **kwargs)
#      34 self._axes_class.__init__(self, fig, [0, 0, 1, 1], **kwargs)
#      35 # This will also update the axes position.
# ---> 36 self.set_subplotspec(SubplotSpec._from_subplot_args(fig, args))
#
# File c:\users\aashay doshi\desktop\projects\raft\venv\lib\site-packages\matplotlib\gridspec.py:604, in SubplotSpec._from_subplot_args(figure, args)
#     602 else:
#     603     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 604         raise ValueError(
#     605             f"num must be 1 <= num <= {rows*cols}, not {num!r}")
#     606     i = j = num
#     607 return gs[i-1:j]
#
# ValueError: num must be 1 <= num <= 1, not 2
